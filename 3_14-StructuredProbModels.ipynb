# %%
# Machine learning algorithms often involve probability distributions over a very large number of random variables. 
# Often, these probability distributions involve irect interactions between relatively few variables. 
# Using a single function to describe the entire joint probability distribution can be very inefficient (both omputationally and statistically).
# Instead of using a single function to represent a probability distribution, we can split a probability distribution into many factors that we multiply together.

# %% [markdown]
# ![image.png](attachment:6ec6755e-cf76-493e-ba29-8ed7ef9eea71.png)

# %%
# a influences b abd b influences c
# a and c are independent given b

# we can greatly reduce the cost of representing a distribution if we are able to find a factorization into distributions over fewer variables
# We can describe these kinds of factorizations using graphs
# # graph --> a set of vertices that may be connected to each other with edges
# When we represent the factorization of a probability distribution with a graph, we call it a structured probabilistic model or graphical model.

# %%
# 2 types of structured probabilistic models:
# # directed
# # undirected
# Both use graph G where each node corresponds to random variable and edges mean that probability distribution can represent direct interactions between vertices

# %%
# Directed:
# # use graphs with directed edges
# # represent factorisations into conditional probability distributions
# # Specifically: 
# # # Such model contains 1 factor for every random variable xi in the distribution
# # # That factor consists of conditional distribution over xi, given parents of Xi --> PaG(xi)

# %% [markdown]
# ![image.png](attachment:e29ba8a6-e8f1-4ad2-96b6-a5458dd5c0fa.png)

# %% [markdown]
# ![image.png](attachment:286c2267-ba04-4eba-9b10-6b10d1021c30.png)

# %%
# Undirected:
# # use graphs with undirected edges
# # represent factorisations into a set of functions
# # typically, these are not probability distributions
# Any set of nodes that are all connected to each other in G is called a clique.
# Each clique C(i) in an undirected model is associated with a factor φ(i)(C(i)).
# These factors are just functions, not probability distributions
# The output of each factor must be non-negative, but there is no constraint that the factor must sum or integrate to 1 like a probability distribution.
# The probability of a configuration of random variables is proportional to the product of all of these factors—assignments that result in larger factor values are more likely
# Of course, there is no guarantee that this product will sum to 1.
# We therefore divide by a normalizing constant Z, defined to be the sum or integral over all states of the product of the φ functions, in order to obtain a normalized probability distribution

# %% [markdown]
# ![image.png](attachment:8cb54dd6-5934-4838-9f54-abaa38c5bc4e.png)

# %% [markdown]
# ![image.png](attachment:cb9b4640-9bda-40cd-bd92-8aba16bdd407.png)![image.png](attachment:23849d35-c2de-4eaa-847f-eac7d1fff589.png)
