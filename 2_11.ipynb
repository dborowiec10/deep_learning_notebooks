# %%
import numpy as np
import matplotlib.pyplot as plt


# the determinant

# The determinant of a matrix A is a number corresponding to the multiplicative change you get when you transform your space with this matrix

# negative determinant means that there is a change in orientation and not just a rescaling and/or a rotation

# a change in orientation means for instance in 2D that we take a plane out of these 2 dimensions, do some transformations and get back to the initial 2D space

# %% [markdown]
# ![image.png](attachment:f42f1d15-06fd-45e6-a5b3-576e21a4a158.png)

# %%
# If you take the n-dimensional unit cube and apply the matrix A on it, the absolute value of the determinant corresponds to the area of the transformed figure

# %%
def plotVectors(vecs, cols, alpha=1):
    """
    Plot set of vectors.

    Parameters
    ----------
    vecs : array-like
        Coordinates of the vectors to plot. Each vectors is in an array. For
        instance: [[1, 3], [2, 2]] can be used to plot 2 vectors.
    cols : array-like
        Colors of the vectors. For instance: ['red', 'blue'] will display the
        first vector in red and the second in blue.
    alpha : float
        Opacity of vectors

    Returns:

    fig : instance of matplotlib.figure.Figure
        The figure of the vectors
    """
    plt.figure()
    plt.axvline(x=0, color='#A9A9A9', zorder=0)
    plt.axhline(y=0, color='#A9A9A9', zorder=0)

    for i in range(len(vecs)):
        x = np.concatenate([[0,0],vecs[i]])
        plt.quiver([x[0]],
                   [x[1]],
                   [x[2]],
                   [x[3]],
                   angles='xy', scale_units='xy', scale=1, color=cols[i],
                   alpha=alpha)

# %% [markdown]
# ![image.png](attachment:07bb88a4-68a1-4eca-ad3b-edccf6db5a21.png)

# %%
# The lengths of i and j are 1 thus the area of the unit square is 1.
    
orange = '#FF9A13'
blue = '#1190FF'

i = [0, 1]
j = [1, 0]

plotVectors([i, j], [[blue], [orange]])
plt.xlim(-0.5, 3)
plt.ylim(-0.5, 3)
plt.show()

# %%
# lets apply a square matrix to them

A = np.array([
    [2, 0],
    [0, 2]
])

new_i = A.dot(i)
new_j = A.dot(j)
plotVectors([new_i, new_j], [['#1190FF'], ['#FF9A13']])
plt.xlim(-0.5, 3)
plt.ylim(-0.5, 3)
plt.show()

# %%
# As expected, we can see that the square corresponding to i and j didn’t rotate but the lengths of i and j have doubled.

# %% [markdown]
# ![image.png](attachment:66eda001-5e25-4884-9e62-c4688047099b.png)

# %%
# now onto calculation of determinant of A

detA = np.linalg.det(A)

# And yes, the transformation have multiplied the area of the unit square by 4. The lengths of newi and newj are 2 (thus 2⋅2=4).

# %%
# now example of negative determinant

B = np.array([
    [-2, 0],
    [0, 2]
])

# determinant is -4
B = np.array([[-2, 0], [0, 2]])
detB = np.linalg.det(B)

new_i_1 = B.dot(i)
new_j_1 = B.dot(j)
plotVectors([new_i_1, new_j_1], [['#1190FF'], ['#FF9A13']])
plt.xlim(-3, 0.5)
plt.ylim(-0.5, 3)
plt.show()

# %% [markdown]
# ![image.png](attachment:124f568e-ad7c-43c0-b30b-39e6c634544a.png)

# %%
# some other random points...
points = np.array([[1, 3], [2, 2], [3, 1], [4, 7], [5, 4]])

# %%
C = np.array([[-1, 0], [0, 1]])
np.linalg.det(C)
# Out:
# -1.0

# %%
newPoints = points.dot(C)

plt.figure()
plt.plot(points[:, 0], points[:, 1])
plt.plot(newPoints[:, 0], newPoints[:, 1])
plt.show()
