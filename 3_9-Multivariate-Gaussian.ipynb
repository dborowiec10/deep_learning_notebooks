# %%
import numpy as np
import matplotlib.pyplot as plt

# Multivariate Gaussian Distribution (Normal Distribution):
# Normal distribution generalized to Rn dimensions

# %% [markdown]
# ## Probability Density Function

# %% [markdown]
# ![image.png](attachment:c539fb57-eeac-4d4f-b1a5-9eb1a298a359.png)

# %%
# or ...

# %% [markdown]
# ![image.png](attachment:e4a1df88-fe97-4f7a-9108-06ebdeffe767.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
from scipy.stats import multivariate_normal
N = 60
X = np.linspace(-3, 3, N)
Y = np.linspace(-3, 4, N)
X, Y = np.meshgrid(X, Y)

mu = np.array([0., 1.])
SigmaSum = np.array([
    [ 1. , -0.5],
    [-0.5,  1.5]
])

pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X
pos[:, :, 1] = Y

Z = multivariate_normal.pdf(pos, mean=mu, cov=SigmaSum)

# Create a surface plot and projected filled contour plot under it.
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, Z, rstride=3, cstride=3, linewidth=1, antialiased=True, cmap=cm.viridis)
cset = ax.contourf(X, Y, Z, zdir='z', offset=-0.15, cmap=cm.viridis)

# Adjust the limits, ticks and view angle
ax.set_zlim(-0.1,0.2)
ax.set_zticks(np.linspace(0,0.2,5))
ax.view_init(10, -27)

plt.show()

# %%
# CDF - probability that x will take value less than or equal to x'
Z = multivariate_normal.cdf(pos, mean=mu, cov=SigmaSum)

# Create a surface plot and projected filled contour plot under it.
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, Z, rstride=3, cstride=3, linewidth=1, antialiased=True, cmap=cm.viridis)
cset = ax.contourf(X, Y, Z, zdir='z', offset=-0.15, cmap=cm.viridis)

# Adjust the limits, ticks and view angle
ax.set_zlim(-0.1,0.2)
ax.set_zticks(np.linspace(0,0.2,5))
ax.view_init(10, -27)

plt.show()
