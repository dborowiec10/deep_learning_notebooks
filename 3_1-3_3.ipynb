# %% [markdown]
# A probability distribution is a description of how likely a random variable or set of random variables is to take on each of its possible states.
# The way we describe probability distributions depends on whether the variables are discrete or continuous.

# %% [markdown]
# The goal of probability is to deal with uncertainty. It gives ways to describe random events. A random variable is a variable that can take multiple values depending on the outcome of a random event. The possible outcomes are the possible values taken by the variable.

# %% [markdown]
# If the outcomes are finite (for example the 6 possibilities in a die throwing event) the random variable is said to be discrete.

# %% [markdown]
# If the possible outcomes are not finite (for example, drawing a number between 0 and 1 can give an infinite number of values), the random variable is said to be continuous.

# %% [markdown]
# One very important thing is to know if some values will be more often encountered than others. The description of the probability of each possible value that a random variable can take is called its probability distribution

# %% [markdown]
# Anyway, the probability distribution of a random variable x describes the probability of each outcome (a probability of 1 meaning that the variable will always take this value and a probability of 0 that it will never be encountered).

# %% [markdown]
# This function is called probability distribution. More specifically, it is called *the probability mass* function for a discrete variable and *probability density function* for a continuous variable.

# %% [markdown]
# The probability mass function is the function which describes the probability associated with the random variable x. This function is named P(x) or P(x=x) to avoid confusion. P(x=x) corresponds to the probability that the random variable x take the value x (note the different typefaces).

# %%
# Lets look at dice roll infinitely.
# Then look at proportion of 1, of 2 and so on
# x in this case is the random variable that corresponds to the outcome of the dice roll
# thus, x can take any of the 1,2,3,4,5,6 discrete values
# thus, x is a discrete random variable

# AIM of the probability mass function is to describe the probability of each possible value of the random variable.
# probability to get 1, to get 2 etc.
# For dice, we have the same probability to get 1,2,3,4,5 and 6 so
# P(x = 1) = P(x = 2) ... P(x = 6)
# So probability to get each value such as 1 is P(x = 1) = 1/6
# With same probability for each variable, the distribution is called uniform distribution

# %% [markdown]
# ![image.png](attachment:f563b02a-8cd3-4bcd-8c4b-9c7231c84d41.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

num_throws = 10000
outcomes = np.zeros(num_throws)
for i in range(num_throws):
    outcome = np.random.choice(['1', '2', '3', '4', '5', '6'])
    outcomes[i] = outcome
    
val, count = np.unique(outcomes, return_counts=True)
proportion = count / len(outcomes)

plt.bar(val, proportion)
# Out:
# <BarContainer object of 6 artists>

# %%
# Joint probability distribution:
# What happens when we roll 2 dice?
# we now have 2 random variables, each corresponding to separate dice
# we also have 2 probability mass functions associated with each variable

# Why would we care?
# Interesting when we want to know probability of x taking a specific value when y takes specific value
# i.e. what's the probability of x = 1 and y = 3
# Notation: P(x = x, y = y) = P(x,y)
# so probability of P(x = 1, y = 3) = 1/6 * 1/6 = 1/36 = 0.028~
# sum of probabilities of each values for a random variable must add up to 1

# %%
# Continuous Variable and Probability Density Function
# used to describe probabilites when values are non-discrete (continuous)
# cannot use y axis for probability here
# must calculate area under curve to get probabilities

# %%
# Lets say we have a random variable x that can take values between 0 and 1 = infinitely large number of values

# %% [markdown]
# ![image.png](attachment:4b494663-27dd-418a-b7ad-ad9f106a64ab.png)

# %%
# for this variable, it is unlikely we will get a 1 or 0 but quite likely that value will be somewhere around 0.3
# need to calculate area under curve to determine probability of a range between 0 and 1 for x

# %% [markdown]
# ![image.png](attachment:5f5a75e2-92ce-4e00-89ca-5892297d5ef0.png)

# %%
# Example:

x = np.random.uniform(0, 0.5, 10000)
sns.distplot(x)
plt.show()
# Out:
# /home/damian/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# however, this variable is continous and still represented by bars? weird
# we must first discretize the function - make it discrete

x = np.random.uniform(0, 0.5, 10000)
sns.distplot(x, bins = 1000)
plt.show()
# Out:
# /home/damian/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Variability is greater than before because we took more bins.
# smaller number of values were in each bin leading to less accurate estimate
# try again with more samples

x = np.random.uniform(0, 0.5, 1000000)
sns.distplot(x, bins = 1000)
plt.show()
# Out:
# /home/damian/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# In probability density function, the probability is described by the area under the curve
# This means the area must add up to 1 to describe probabilities
# in this case, multiply height by width of the distribution 2 * 0.5 = 1
# but in many cases, area under the curve is not square...
# still need to calculate area. How?

# %% [markdown]
# ![image.png](attachment:2578e094-fa40-4313-a56d-7658909787df.png)

# %%
# Can look at integral of the function
# oppositve of calculating the derivative
# if you derive a function and then calculate integral of resulting function you will get original function

# derivative at a point of a function gives rate of change

# %%
# lets model speed of vehicle
# we have a function: f(x) = x^2 which describes speed of vehicle as a function of time

x = np.arange(-10, 11, 0.1)

fx = x ** 2

plt.plot(x, fx)
plt.xlim(-4, 4)
plt.ylim(-1, 10)
# Out:
# (-1.0, 10.0)

# %%
# speed increases slowly at beginning but increases more and more for a constant duration
# it doesn't make sense to have negative values...

x = np.arange(0, 11, 0.1)
fx = x ** 2
plt.plot(x, fx)
plt.xlim(-1, 4)
plt.ylim(-1, 10)
# Out:
# (-1.0, 10.0)

# %%
# derivative of this function is f'(x) = 2x

x = np.arange(-10, 11)
fx = 2*x
plt.plot(x, fx)
plt.xlim(0, 10)
plt.ylim(0, 10)

# it decribes the rate of change of y in respect of x
# in this context, it describes acceleration

# so... the graph below shows that acceleration of the vehicle increases linearly with time
# so, when x = 0, rate of change is 2*0 = 0. When x is 3, rate of change is 6
# this means that at that point, speed increased by 6 when time increased by 1
# Out:
# (0.0, 10.0)

# %%
# Integrals
# reverse of derivatives
# going from rate of change to change itself
# f'(x) or the integral of a function gives us f(x) back

# %% [markdown]
# ∫f′(x)dx=f(x)

# %%
# dx means we integrate over x, to say we sum slices weighted by y

# %% [markdown]
# ∫2xdx = x^2 + c

# %%
# we add constant c
# because infinite number of functions could have given the derivative 2x - i.e. x^2 + 294, x^2 + 3 ...
# we lose a bit of information and cannot recover it

# %%
# 2x is the function describing the rate of change (slope) of the function x^2

# %%
# now... to go from f'(x) to f(x)
# the area under the curve of f'(x) corresponds to f(x)

# the area under the curve increases exponentially.
# For different ranges [0 - 0], [0 - 1] ...
# we can calculate the area under the curve using Pythagorean theorwem and dividing by 2 since areas are half squares

# %% [markdown]
# We can integrate the density function to find the actual probability mass of a
# set of points. Specifically, the probability that x lies in some set S is given by the
# integral of p(x) over that set. In the univariate example, the probability that x
# lies in the interval [a, b] is given by ∫[a,b]p(x)dx.

# %% [markdown]
# A probability density function p(x) does not give the probability of a specific
# state directly, instead the probability of landing inside an infinitesimal region with
# volume δx is given by p(x)δx.
