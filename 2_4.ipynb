# %%
import numpy as np
import matplotlib.pyplot as plt
import plot_vec

# %%
# function to plot multiple vectors
orange = '#FF9A13'
blue = '#1190FF'

def plotVectors(vecs, cols, alpha=1):
    """
    Plot set of vectors.

    Parameters
    ----------
    vecs : array-like
        Coordinates of the vectors to plot. Each vectors is in an array. For
        instance: [[1, 3], [2, 2]] can be used to plot 2 vectors.
    cols : array-like
        Colors of the vectors. For instance: ['red', 'blue'] will display the
        first vector in red and the second in blue.
    alpha : float
        Opacity of vectors

    Returns:

    fig : instance of matplotlib.figure.Figure
        The figure of the vectors
    """
    plt.figure()
    plt.axvline(x=0, color='#A9A9A9', zorder=0)
    plt.axhline(y=0, color='#A9A9A9', zorder=0)

    for i in range(len(vecs)):
        x = np.concatenate([[0,0],vecs[i]])
        plt.quiver([x[0]],
                   [x[1]],
                   [x[2]],
                   [x[3]],
                   angles='xy', scale_units='xy', scale=1, color=cols[i],
                   alpha=alpha)

# %%
# equation 
# Ax = b

# can have
# 0 solutions 
# 1 solution = lines intersect
# infinite solutions = lines interposed

# %%
# d and e are 2 solutions to the system Ax = b
# Ad = b
# Ae = b

# %%
# potential solution is: Az = b where z = ad + (1 - a)e for any value of a
# Az = A(ad + (1 - a)e)
#    = Ada + Ae(1 - a)

# %%
# we also know that
# Ad = Ae = b
# so...
# Az = ba + b(1 - a)
#    = ba + b - ba
#    = b
# So Az = b and z is also a solution

# %% [markdown]
# ![image.png](attachment:4e291231-5633-4502-b52d-9a6e9f7f9fa2.png)

# %%
# The number of columns of A is the number of dimensions of the vector space.

# %%
# the linear system can be characterized with its number of equations (m) and the number of unknown variables (n).

# %%
# If there are more equations than unknows the system is called overdetermined

# %%
# If there is more unknowns than equations the system is called underdetermined

# %% [markdown]
# ![image.png](attachment:8ea40565-89c9-4da0-8945-cf45d234c5cc.png)

# %% [markdown]
# ![image.png](attachment:b05c380b-3260-4dff-9d7b-4fe056389556.png)

# %% [markdown]
# ![image.png](attachment:ef8aedde-009d-4b37-aabb-565fbeb4fa05.png)

# %%
# we have a 2-D space so can be represented with 2 axes.
# hyperplane is n-1 so it is 1-D - a line
# 1 equation = 1 line characterizing the system

# %%
# y = ax + b   --> can also be used to represent the same equation where...
# y = x2
# x = x1
# a = A1,1
# 1 = A1,2

# %%
# lets examine equation y = 2x + 1

# %%
x = np.arange(-10, 10)
y = 2*x + 1

# %%
plt.figure()
plt.plot(x, y)
plt.xlim(-2, 10)
plt.ylim(-2, 10)
plt.axvline(x=0, color='grey')
plt.axhline(y=0, color='grey')

# %%
# solutions to this linear system correspond to values of x and y
# graphically, corresponds to each point on the line
# infinite number of solutions
# i.e. solutions could be x=0 & y=1 or x=1 & y=3

# %% [markdown]
# ![image.png](attachment:2a746824-1734-457e-aea7-649cef810722.png)

# %%
# lets examine equations: 
# y = 2x + 1
# y = 6x - 2

# %%
x = np.arange(-10, 10)
y = 2*x + 1
y1 = 6*x - 2

# %%
plt.figure()
plt.plot(x, y)
plt.plot(x, y1)
plt.xlim(-2, 10)
plt.ylim(-2, 10)
# draw axes
plt.axvline(x=0, color='#A9A9A9')
plt.axhline(y=0, color='#A9A9A9')

# %%
# On the above figure, the two lines are crossing so there is one unique solution
# If they are superimposed there are a infinite number of solutions since each points of the lines corresponds to an intersection
# If they are parallel, there is no solution.

# %% [markdown]
# ![image.png](attachment:6880fc9f-0c6e-4be1-ab8e-5541bc5d0b83.png)

# %%
x = np.arange(-10, 10)
y = 2*x + 1
y1 = 6*x - 2
y2 = 0.1*x+6

# %%
plt.figure()
plt.plot(x, y)
plt.plot(x, y1)
plt.plot(x, y2)
plt.xlim(-2, 10)
plt.ylim(-2, 10)
# draw axes
plt.axvline(x=0, color='#A9A9A9')
plt.axhline(y=0, color='#A9A9A9')

# %%
# In the above case, there is 3 equations and no solution because there is no point in space that is on each of these lines.

# %%
# Linear combination...

# %%
# The linear combination of 2 vectors corresponds to their weighted sum.

# %%
uw = [] # some weights for vector w
u = [
    [1],
    [3]
]
vw = [] # some weights for vector v
v = [
    [2],
    [1]
]
# Linear combination of u & v is:
# uw*u + vw*v

# %%
# Graphically, the vectors are added to reach a specific point in space. For example if a=2 and b=1:

# %% [markdown]
# ![image.png](attachment:dde56392-396f-4ae8-aed6-794f10f23011.png)

# %%
# The sum of u and v is a vector that will reach the point of corrdinates (4,7)

# %%
plotVectors([
    [1, 3],
    [2, 1]
], [orange, blue])
plt.xlim(0, 5)
plt.ylim(0, 5)
# Out:
# (0.0, 5.0)

# %%
# weights
a = 2
b = 1

# vector coordinates
u = [0, 0, 1, 3]
v = [2, 6, 2, 1]

plt.quiver([u[0], a*u[0], b*v[0]],
           [u[1], a*u[1], b*v[1]],
           [u[2], a*u[2], b*v[2]],
           [u[3], a*u[3], b*v[3]],
           angles='xy', scale_units='xy', scale=1, color=[orange, orange, blue])
plt.xlim(-1, 8)
plt.ylim(-1, 8)
# Out:
# (-1.0, 8.0)

# %%
# span of vectors u and v is the set of points that can be reached by changing the combinations of a and b

# %%
# The space of a vector determines all the values that can be taken by this vector.

# %%
# column figure

# %%
# It is also possible to represent the set of equations by considering that the solution
# vector b corresponds to a linear combination of each columns multiplied by their weights.

# %% [markdown]
# ![image.png](attachment:d5435053-7e89-4b2a-bc4c-6672c980afb0.png)

# %%
# The column representation is

# %% [markdown]
# ![image.png](attachment:d21c7072-133f-409a-b183-a2aeb51d4696.png)

# %%
# The columns of A give us the directions we can travel by and their weights are the length of the way in that direction.

# %% [markdown]
# ![image.png](attachment:2cc34671-7070-43c7-80d8-9a0174eb8f05.png)

# %%
# Variables known are
#     [1/2  -1]
#     [1     1]

# as such the column figure is:

#     [1/2]       [-1]   [-1]
# x * [1  ] + y * [1]  = [4 ]

# goal is to find x and y such that combination of the variables and weights produces the vector [-1, 4]

# %%
x = np.arange(-10, 10)

y = 0.5 * x + 1
y1 = -x + 4

# %%
plt.figure()
plt.plot(x, y)
plt.plot(x, y1)
plt.xlim(-2, 10)
plt.ylim(-2, 10)
# draw axes
plt.axvline(x=0, color='#A9A9A9')
plt.axhline(y=0, color='#A9A9A9')

# %%
# We can see that the solution (the intersection of the lines representing our two equations) is x=2 and y=2.

# %% [markdown]
# ![image.png](attachment:2d1b1cca-21e6-4780-8598-714b9e293a64.png)

# %%
u = [0, 0, 0.5, 1]
u_bis = [u[2], u[3], u[2], u[3]]
v = [2 * u[2], 2 * u[3], -1, 1]
v_bis = [2 * u[2]-1, 2 * u[3] + 1, v[2], v[3]]

plt.quiver([u[0], u_bis[0], v[0], v_bis[0]],
           [u[1], u_bis[1], v[1], v_bis[1]],
           [u[2], u_bis[2], v[2], v_bis[2]],
           [u[3], u_bis[3], v[3], v_bis[3]],
           angles='xy', scale_units='xy', scale=1, color=[blue, blue, orange, orange])
plt.xlim(-1.5, 2)
plt.ylim(-0.5, 4.5)
# Out:
# (-0.5, 4.5)

# %%
# We can see that it is working! We arrive to the point (−1, 4).

# %%
# Now we need to determine if the system has one and only one solution for every value of b
# such system would be "determined"
# 2 requirements

# %%
# 1. system must have at least 1 solution
# 2. system must have at most 1 solution

# %%
# Requirement 1: system is underdetermined: i.e. find b such that n >= m
# i.e. 2 equations and 3 unknown variables

# %% [markdown]
# ![image.png](attachment:7c53a67c-0119-4af3-b194-4bcccca435c0.png)

# %% [markdown]
# ![image.png](attachment:e2f2d65f-9812-4b70-b84b-7c6564a607c4.png)

# %% [markdown]
# We can see that in the best case the two planes are not parallel and there are solutions to the set of equations. It means that it exists some points that rely on both planes. But we can also see that there is inevitably an infinite number of points on the intersection (a line that we can see on the figure). We need a third plane to have a unique solution.

# %%
# Requirement 2: system is overdetermined: i.e. find b such that n <= m
# i.e. 3 equations and 2 unknown variables.

# %% [markdown]
# The column figure is helpful to understand why the linear system has usually no solution if n (the number of unknowns) is smaller than m (the number of equations). Let’s add 1 equation to the above system in order to end up with a (3×2) matrix (3 equations and 2 unknowns):

# %% [markdown]
# ![image.png](attachment:a86dbeda-6aa7-41c3-88e3-1487de9d0d86.png)

# %% [markdown]
# So we are still traveling in our 2-dimensional space (see the plot of the column space above) but the point that we are looking for is defined by 3 dimensions. There are cases where the third coordinate does not rely on our 2-dimensional x-y plane. In that case no solution exists.

# %%
# Linear dependence:

# The number of columns can thus provide information on the number of solutions. 
# But the number that we have to take into account is the number of linearly independent columns.
# Columns are linearly dependent if one of them is a linear combination of the others
# Thinking in the column picture, the direction of two linearly dependent vectors is the same

# %%
# Example of a system containing linear dependency

# %% [markdown]
# ![image.png](attachment:494d9fc7-0743-46ef-b71d-ba5b6ea1d8d6.png)

# %%
# Row figure:

# %%
x = np.arange(-10, 10)
y = 2*x + 6
y1 = 2*x

# %%
plt.figure()
plt.plot(x, y)
plt.plot(x, y1)
plt.xlim(-2, 10)
plt.ylim(-2, 10)
# draw axes
plt.axvline(x=0, color='#A9A9A9')
plt.axhline(y=0, color='#A9A9A9')

# %%
# Column figure:

# %% [markdown]
# ![image.png](attachment:a8be3797-74f9-49df-b0a9-448c286fb786.png)

# %%
u = [0,0,2,2]
v = [0,0,-1,-1]

plt.quiver([u[0], v[0]],
           [u[1], v[1]],
           [u[2], v[2]],
           [u[3], v[3]],
           angles='xy', scale_units='xy', scale=1, color=[blue, orange])
plt.xlim(-7, 3)
plt.ylim(-2, 3)
# draw axes
plt.axvline(x=0, color='#A9A9A9')
plt.axhline(y=0, color='#A9A9A9')
plt.scatter(-6,0,marker='x',s=150)

# %%
# We would like to go to b but the only path we can take is the blue/orange line
# The second equation doesn’t provide us with a new direction to take since it is just a linear combination of the first one
# Thus, an overdetermined system of independant equations has at most 1 solution.

# %%
# How could we satisfy both requirements (m≥n and n≥m): we must have m=n!

# %%
# The result of all of this is that the system needs a square matrix
# A(m=n) with linearly independant columns to have a unique solution for every value of b.

# %%
# The inverse of a matrix exists only if the set of equations has one and only one solution for each value of b because:

# %%
# The matrix A cannot have more than 1 inverse.
# Imagine that A has 2 inverses B and C such as AB=I and AC=I.
# This would mean that B=C.

# The solution of the system Ax=b is x=A−1b.
# So if there are multiple solutions, there are multiple inverses and the first point is not met.
