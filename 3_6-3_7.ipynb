# %%
# Independence and Comnditional Independence

# 2 random variables x and y are independent if their probability distribution can be expressed as a product of 2 factors
# 1 involving only x and one involving only y

# %% [markdown]
# ![image.png](attachment:321ae800-7712-497d-bfc1-ced96e0badc2.png)

# %%
# for their independence to be conditional given some random variable z, their conditional probability distribution over x and y factorizes in this way for every value of z

# %% [markdown]
# ![image.png](attachment:12ef29e1-93d9-4857-b15a-446481289ae8.png)

# %%
# Chain Rule of Conditional Probabilities

# ANY joint probability distribution over many random variables may be decomposed into
# conditional distributions over only one variable

# %% [markdown]
# ![image.png](attachment:9497065b-bc0d-43a1-9287-5631711fdb6f.png)

# %%
# as each probability is dependent on joint probability of variables from 1 to i - 1, the chaining occurs
# for variable x1 to take value x, all other x2 --> xn variables must have taken some respective values

# %% [markdown]
# ![image.png](attachment:b2342ecd-961c-4266-a53f-0a66d101d3a0.png)
